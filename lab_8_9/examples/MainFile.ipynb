# %%
import numpy as np
import matplotlib.pyplot as plt
import pyswarms as ps
from pyswarms.utils.plotters import (plot_cost_history, plot_contour, plot_surface)
from pyswarms.utils.functions import single_obj as fx

from pyswarms.utils.plotters.formatters import Mesher

from IPython.display import IFrame

# %%
# %run -i functions.ipynb --cell 0

# %%
options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}
max_bound = [5, 5]
min_bound = [-5, -5]
bounds = (min_bound, max_bound)
# Call instance of PSO
optimizer = ps.single.GlobalBestPSO(n_particles=50, dimensions=2, options=options, bounds=bounds)

# %%
# Perform optimization
cost, pos = optimizer.optimize(func, iters=100)
plot_cost_history(cost_history=optimizer.cost_history), plt.grid('on')
plt.show()

m = Mesher(func=func)
FileName = 'plot_func.gif'
animation = plot_contour(pos_history=optimizer.pos_history, mesher=m, mark=(0,0))
animation.save(FileName, writer='imagemagick', fps=10)
# Out:
# 2024-05-07 10:51:13,859 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=0.000386
# 2024-05-07 10:51:14,754 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.00038628870272362087, best pos: [-3.38871156e-05  3.52401587e-04]
# 2024-05-07 10:51:23,801 - matplotlib.animation - WARNING - MovieWriter imagemagick unavailable; using Pillow instead.
# 2024-05-07 10:51:23,804 - matplotlib.animation - INFO - Animation.save using <class 'matplotlib.animation.PillowWriter'>

# %%
IFrame(src=FileName, width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="plot_func.gif"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
cost, pos = optimizer.optimize(fx.sphere, iters=500)
plot_cost_history(cost_history=optimizer.cost_history), plt.grid('on')
plt.show()

m = Mesher(func=fx.sphere)
FileName = 'plot_sphere.gif'
animation = plot_contour(pos_history=optimizer.pos_history, mesher=m, mark=(0,0))
animation.save(FileName, writer='imagemagick', fps=10)
# Out:
# 2024-05-07 10:52:25,221 - pyswarms.single.global_best - INFO - Optimize for 500 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|500/500, best_cost=2.27e-31
# 2024-05-07 10:52:28,879 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.269898020697066e-31, best pos: [-4.25674539e-16  2.13988292e-16]
# 2024-05-07 10:52:44,687 - matplotlib.animation - WARNING - MovieWriter imagemagick unavailable; using Pillow instead.
# 2024-05-07 10:52:44,692 - matplotlib.animation - INFO - Animation.save using <class 'matplotlib.animation.PillowWriter'>

# %%
IFrame(src=FileName, width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="plot_sphere.gif"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
cost, pos = optimizer.optimize(fx.rastrigin, iters=500)
plot_cost_history(cost_history=optimizer.cost_history), plt.grid('on')
plt.show()

m = Mesher(func=fx.rastrigin)
FileName = 'plot_rastrigin.gif'
animation = plot_contour(pos_history=optimizer.pos_history, mesher=m, mark=(0,0))
animation.save(FileName, writer='imagemagick', fps=10)
# Out:
# 2024-05-07 10:58:44,761 - pyswarms.single.global_best - INFO - Optimize for 500 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|████████████████████████████████████████████████████████████████|500/500, best_cost=0
# 2024-05-07 10:58:47,075 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [3.23722904e-11 2.15545872e-13]
# 2024-05-07 10:58:57,212 - matplotlib.animation - WARNING - MovieWriter imagemagick unavailable; using Pillow instead.
# 2024-05-07 10:58:57,215 - matplotlib.animation - INFO - Animation.save using <class 'matplotlib.animation.PillowWriter'>

# %%
IFrame(src=FileName, width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="plot_rastrigin.gif"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
