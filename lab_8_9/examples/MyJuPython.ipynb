# %% [markdown]
# # gchjflgh
# ## gfdfgfgdjdfjhgj
# ##### gfdfgfdhlfh
# dfjfhlfjlhhkl
#
# dfghfkf $\int_{2}^{4}\sin\left(\frac{2}{5}\right)dx$ df gfhk khfhf h

# %%
from math import log, pi
# import math as m

x, y = 2, 4
z = x + y
print('x =', x, '. y =', y)
print('z =',z)

'''
a = 4; b = 6
print('a =', a, '. b =', b)
'''

x = "Sleep, Mar'yana"
y = x +'! '
y = 10*y
print(y)

x = 20

y1 = log(x)
y2 = log(x,15)
print(y1, y2)

x = input('Введіть число: ')
y = x+str(1)
print(y)
print(pi)

print(round(2.5000011))
# Out:
# x = 2 . y = 4
# z = 6
# Sleep, Mar'yana! Sleep, Mar'yana! Sleep, Mar'yana! Sleep, Mar'yana! Sleep, Mar'yana! Sleep, Mar'yana! Sleep, Mar'yana! Sleep, Mar'yana! Sleep, Mar'yana! Sleep, Mar'yana!
# 2.995732273553991 1.106232178537418
# Введіть число: 8
# 81
# 3.141592653589793
# 3
